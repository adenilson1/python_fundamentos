# %% [markdown]
# # Estrutura de Repetição - Loop While

# %%
contador = 5

print("\nContagem regressiva")

while contador > 0:
    print(contador)
    contador -= 1
# Out:
# Contagem regressiva
# 5
# 4
# 3
# 2
# 1

# %%
contador = 0

print("Contagem regressiva")

while contador > 1:
    print(contador)
    contador -= 1
# Out:
# Contagem regressiva

# %%
# cuidadeo com loop infinito

contador = 2

print("\nContagem regressiva:")

while co
