# %% [markdown]
# # Logica de programação, Varáveis, Tipos e Estruturas de Dados - parte 1

# %% [markdown]
# ## Variáveis: Declaração, Atribuição e Regras de Nomeclatura

# %%
#Declaração de varávies
nome_completo = "Bob da Silva"
idade = 30
altura = 1.76
eh_estudante = True

# %%
print(f"Nome: {nome_completo}")
print(f"Idade: {idade}")
print(f"Altura: {altura}")
print(f"É estudante? {eh_estudante}")
# Out:
# Nome: Bob da Silva
# Idade: 30
# Altura: 1.76
# É estudante? True

# %%
# Exemplo de erro
#1nome = "Inválido"
nome-completo = "inválido"
# Out:
#   Cell In[3], line 3
#     nome-completo = "inválido"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?
