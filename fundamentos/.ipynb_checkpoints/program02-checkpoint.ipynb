# %% [markdown]
# # Dinamicamente tipada

# %%
# Não é necessário declarar o tipo da variável em python

x = 10
y1 = 10
y2 = "10"

# %%
type(x)
# Out:
# int

# %%
type(y1)
# Out:
# int

# %%
type(y2)
# Out:
# str

# %%
# pode somar tipos numericos
print(x + y1)
# Out:
# 20

# %%
# nao somar tipos diferente
print(x + y2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # nao somar tipos diferente
# ----> 2 print(x + y2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
